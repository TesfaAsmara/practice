# %% [markdown]
# # 1.6
#
# > Problems

# %% [markdown]
# # 1.6.1
#
# > The 3n + 1 Problem

# %%
def process(n):
    # store our generated sequence
    sequence = [n]
    while n > 1:
        # check if even
        n_is_even = n % 2 == 0
        if (n_is_even):
            n = n/2
            sequence.append(n)
        else:
            n = (n*3)+1
            sequence.append(n)
    return sequence

process(22)
# Out:
# [22,
#  11.0,
#  34.0,
#  17.0,
#  52.0,
#  26.0,
#  13.0,
#  40.0,
#  20.0,
#  10.0,
#  5.0,
#  16.0,
#  8.0,
#  4.0,
#  2.0,
#  1.0]

# %% [markdown]
# # 1.6.2
#
# > Minesweeper

# %% [markdown]
# I did not get it on the first attempt.

# %%
# for the number of lines
# and columns of the field, respectively. 
# Each of the next n lines contains exactly m
# characters, representing the field.

def minesweeper(file):
    fin = open(file, "r")
    fout = open(file.replace(".in", '.out'), "w")

    input = [x.strip() for x in fin.readlines()]
    def count_mines(i, j, arr):
        for vertical in [-1, 0, 1]:
            for horizontal in [-1, 0, 1]:
                vertical  = i + vertical
                horizontal = j + horizontal
                if vertical < len(arr) and horizontal < len(arr[0]):
                    position = arr[vertical][horizontal]
                    at_mine_position = vertical == horizontal == 0
                    not_already_mine = position != "*"
                    if (at_mine_position):
                        position = "*"
                    elif (not_already_mine):
                        position += 1
        return arr

    def read(index):
        n, m = [int(x) for x in input[index].split()]
        if (n != 0) and (m != 0):
            arr = [[0 for i in range(m)] for i in range(n)]
            for i in range(n):
                for j in range(m):
                        cur_char = input[i+1][j]
                        if cur_char == "*":
                            arr = count_mines(i, j, arr)
            for i, row in enumerate(arr):
                arr[i] = "".join(str(x) for x in row) + "\n"
            return arr, index+n
    
    index = 0
    results = []
    file_not_done = index < len(input)
    while file_not_done:
        index = read(index)
    
    output = ""
    for i, result in enumerate(results):
        output += f"Field #{i}:\n" + "".join(str(x) for x in result)
    print(output)
    fout.write(output)
#minesweeper("1.6.2.in")

# %% [markdown]
# I did get it on the second attempt

# %%
def minesweeper2(file):
    fin = open(file, "r")
    fout = open(file.replace(".in", ".out"), "w")

    def count_mines(arr):
        num_x = len(arr)
        num_y = len(arr[0])
        field = [[0 for i in range(num_y)] for i in range(num_x)]
        for i in range(num_x):
            for j in range(num_y):
                position = arr[i][j]
                if position == "*":
                    field[i][j] = '*'
                    for row in [i+1,i, i-1]:
                        if row >= 0 and row < num_x:
                            for col in [j+1,j, j-1]:
                                if col >= 0 and col < num_y:
                                        if field[row][col] != "*":
                                            field[row][col] += 1
        output = ""
        for i, row in enumerate(field):
            output += "".join(str(x) for x in row) + "\n"
        return output
    
    input = [line.strip() for line in fin.readlines()]
    file_index = 0
    output = ''
    counter = 0
    while file_index < len(input):
        n, m = [int(x) for x in input[file_index].split()]
        if n == 0:
            break
        else:
            counter += 1
            start = file_index+1
            stop = file_index+n+1
            output += f"Field #{counter}:\n{count_mines(input[start:stop])}\n"
            file_index = stop
    fout.write(output)
minesweeper2("1.6.2.in")

# %% [markdown]
# # 1.6.3
#
# > The Trip

# %%
def equalize_cost(file):
    fin = open(file, "r") 
    fout = open(file.replace(".in", ".out"), "w")

    input = [float(f"{float(line.strip()):2f}") for line in fin.readlines()]

    def read(expenses):
        #str(max(abs(x) for x in [x - y if i != j else -1 for i, x in enumerate(expenses) for j, y in enumerate(expenses)]))
        return sum([x if x > 0 else 0 for x in list(map(lambda x: x - float(f"{sum(expenses)/len(expenses):2f}"), expenses))])
    
    file_index = 0
    output = ""
    while file_index < len(input):
        n = int(input[file_index])
        if n != 0:
            start = file_index+1
            stop = file_index+n+1
            output += f"{read(input[start:stop]):2f}\n"
            file_index = stop
        else:
            break
    fout.write(output)
equalize_cost('1.6.3.in')

# %% [markdown]
# # 1.6.4
#
# > LCD Display

# %%
def display(file):
    fin = open(file, "r")
    fout = open(file.replace(".in", ".out"), "w")

    input = [line.split() for line in fin.readlines()]
    
    def print_lcd(spec):
        s = int(spec[0])
        rows = 2*s+3
        cols = s + 2

        
        
        def top_left_col(arr):
            for i in range(1, 1+s):
                arr[i][0] = "|"
        
        def bot_left_col(arr):
            for i in range(int(rows/2)+1, int(rows/2)+1+s):
                arr[i][0] = "|"
        
        def top_right_col(arr):
            for i in range(1, 1+s):
                arr[i][-1] = "|"
        
        def bot_right_col(arr):
            for i in range(int(rows/2)+1, int(rows/2)+1+s):
                arr[i][-1] = "|"
        
        def top_row(arr):
            for i in range(1, 1+s):
                arr[0][i] = "-"
        
        def mid_row(arr):
            for i in range(1, 1+s):
                arr[int(rows/2)][i] = "-"
        
        def bot_row(arr):
            for i in range(1, 1+s):
                arr[-1][i] = "-"

        # hori = " " + "-"*s + "\n"
        # vertl = " " + "|\n"*s 
        # vertl_forlANDr = " " + "|" + " "*s 
        # vertr = "\n" + " "*s + "|\n" 
        nums = spec[1]
        fit_vert = int(rows/(s+1))
        fit_hori = int(cols/(s+1))
        output = []
        for num in nums:
            lcd = [[" " for col in range(cols)] for row in range(rows)]
            if num == "1":
                top_left_col(lcd)
                bot_left_col(lcd) 
            elif num == "2":
                top_row(lcd)
                top_right_col(lcd)
                mid_row(lcd)
                bot_left_col(lcd)
                bot_row(lcd)
            elif num == "3":
                top_row(lcd)
                top_right_col(lcd)
                mid_row(lcd)
                bot_right_col(lcd)
                bot_row(lcd)
            elif num == "4":
                top_left_col(lcd)
                top_right_col(lcd)
                mid_row(lcd)
                bot_right_col(lcd)
            elif num == "5":
                top_row(lcd)
                top_left_col(lcd)
                mid_row(lcd)
                bot_right_col(lcd)
                bot_row(lcd)
            elif num == "6":
                top_row(lcd)
                top_left_col(lcd)
                mid_row(lcd)
                bot_left_col(lcd)
                bot_right_col(lcd)
                bot_row(lcd)
            elif num == "7":
                top_row(lcd)
                top_right_col(lcd)
                bot_right_col(lcd)
            elif num == "8":
                top_row(lcd)
                top_left_col(lcd)
                top_right_col(lcd)
                mid_row(lcd)
                bot_left_col(lcd)
                bot_right_col(lcd)
                bot_row(lcd)
            elif num == "9":
                top_row(lcd)
                top_left_col(lcd)
                top_right_col(lcd)
                mid_row(lcd)
                bot_right_col(lcd)
                bot_row(lcd)
            elif num == "0":
                top_row(lcd)
                top_left_col(lcd)
                top_right_col(lcd)
                bot_left_col(lcd)
                bot_right_col(lcd)
                bot_row(lcd)

            for i, list in enumerate(lcd):
                lcd[i] = " ".join(list)
            output.append(lcd)
            
        result = ["" for row in range(rows)]
        for i, list in enumerate(output):
            for row in range(rows):
                result[row] += output[i][row]
        for row in result:
            fout.write(f"{row}\n")
        fout.write("\n")
    for item in input:
        print_lcd(item)

display("1.6.4.in")

# %% [markdown]
# # 1.6.5
#
# > Graphical Editor

# %%
def graphical_editor(file):
    fin = open(file, "r")
    fout = open(file.replace(".in", ".out"), "w")

    input = [line.split() for line in fin.readlines()]

    def find_region_r(x, y, image, region):
        rows = len(image)
        cols = len(image[0])
        cur_pix = image[x][y]
        n_pix = image[x][y+1] if y+1 < cols else ""
        n_cor = [x, y+1] if y+1 < cols else []
        e_pix = image[x+1][y] if x+1 < rows else ""
        e_cor = [x+1, y] if x+1 < rows else []
        s_pix = image[x][y-1] if y-1 > 0 else ""
        s_cor = [x, y-1] if y-1 > 0 else [] 
        w_pix = image[x-1][y] if x-1 > 0 else ""
        w_cor = [x-1, y] if x-1 > 0 else []
        if cur_pix == n_pix and n_cor not in region:
            region.append(n_cor)
            region.append(find_region_r(n_cor[0], n_cor[1], image, region))
        elif cur_pix == e_pix and e_cor not in region:
            region.append(e_cor)
            region.append(find_region_r(e_cor[0], e_cor[1], image, region))
        elif cur_pix == s_pix and s_cor not in region:
            region.append(s_cor)
            region.append(find_region_r(s_cor[0], s_cor[1], image, region))
        elif cur_pix == w_pix and w_cor not in region:
            region.append(w_cor)
            region.append(find_region_r(w_cor[0], w_cor[1], image, region))
        return region

    def parse_command(list, image):
        command  = list[0]
        if command.startswith("I"):
            m, n = command[1], command[2]
            m = int(m)
            n = int(n)
            image = [["O" for col in range(m)] for row in range(n)]
        elif command.startswith("C"):
                for row in image:
                    for col in image:
                        image[row][col] = "O"
        elif command.startswith("L"):
            x, y, c = command[1], command[2], command[3]
            col = int(x)
            row = int(y)
            image[row][col] = c
        elif command.startswith("V"):
            x, y1, y2, c = command[1], command[2], command[3], command[4]
            for row in range(y1, y2+1):
                image[row][x] = "c"
        elif command.startswith("H"):
            x1, x2, y, c = command[1], command[2], command[3], command[4]
            for col in range(x1, x2+1):
                image[y][col] = c
        elif command.startswith("K"):
            x1, y1, x2, y2, c =command[1], command[2], command[3], command[4], command[5]
            for row in range(y1, y2+1):
                for col in range(x1, x2+1):
                    image[row][col] = c        
        elif command.startswith("F"):
            x, y, c = command[1], command[2], command[3]
            col = int(x)
            row = int(y)
            region = [row, col]
            region_cors = find_region_r(row, col, image, region)
            for cor in region_cors:
                row = cor[0]
                col = cor[1] 
                image[row][col] = c
        elif command.startswith("S"):
            name = list[1]
            output = f"{name}\n"
            for i, row in enumerate(image):
                output+= "".join(row) + "\n"
            fout.write(output)
        elif command.startswith("X"):
            quit()
        return image
    image = []
    for command in input:
        image = parse_command(command, image)
            
graphical_editor("1.6.5.in")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb Cell 14' in <cell line: 85>()
#      <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=81'>82</a>     for command in input:
#      <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=82'>83</a>         image = parse_command(command, image)
# ---> <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=84'>85</a> graphical_editor("1.6.5.in")
#
# /Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb Cell 14' in graphical_editor(file)
#      <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=80'>81</a> image = []
#      <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=81'>82</a> for command in input:
# ---> <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=82'>83</a>     image = parse_command(command, image)
#
# /Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb Cell 14' in graphical_editor.<locals>.parse_command(list, image)
#      <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=66'>67</a> region_cors = find_region_r(row, col, image, region)
#      <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=67'>68</a> for i in range(len(region_cors)):
# ---> <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=68'>69</a>     row = region_cors[i][0]
#      <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=69'>70</a>     col = region_cors[i][1]
#      <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000013?line=70'>71</a>     image[row][col] = c
#
# TypeError: 'int' object is not subscriptable

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb Cell 15' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/tesfaasmara/Documents/GitHub/practice/nbs/usaco/chapter1/programming_challenges/1.6.ipynb#ch0000020?line=0'>1</a> "abc".split("")
#
# ValueError: empty separator
